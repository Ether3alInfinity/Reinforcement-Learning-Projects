# %% [markdown]
# We first install and import necessary packages.

# %%
# !pip install torch
# !pip install swig
# !pip install gymnasium
# !pip install gymnasium[box2d]
# !pip install stable-baselines3
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Collecting swig
#   Downloading swig-4.1.1.post0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.0 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.1.1.post0
# Collecting gymnasium
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.5.2)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.1.1.post0)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2373076 sha256=e57a8ff8f36ef12b622b056bee740581c1b45c750c7eb9e5df550c16c2b7dbf1
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.5
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.2.1

# %%
import gymnasium as gym

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as functional

import matplotlib.pyplot as plt

# %% [markdown]
# ## Lunar Lander
#
# Next, we instantiate the [Lunar Lander environment](https://www.gymlibrary.dev/environments/box2d/lunar_lander/) from OpenAI Gym and gain a quick understanding of its key variables and methods.
#
# The Lunar Lander environment models a rocket that needs to land on the moon. Follow the hyperlinks to learn more about the envionment [Acrobot environment](https://www.gymlibrary.dev/environments/box2d/lunar_lander/). In this assignment, we will use the Continuous (v2) version of the environment in which both the state and action spaces are continuous.
#
# ![](https://www.gymlibrary.dev/_images/lunar_lander.gif)

# %%
env = gym.make("LunarLanderContinuous-v2")

# %% [markdown]
# #### States
#
# OpenAI Gym environments do not explicitly provide state but instead provide observation. In the Lunar Lander environment, the state and observation are identical. The state of the Lander is a 8-dimensional vector: the coordinates of the lander in x and y, its linear velocities in x and y, its angle, its angular velocity, and two booleans that represent whether each leg is in contact with the ground or not.

# %%
print(f"Number of state features: {env.observation_space.shape[0]}")
# Out:
# Number of state features: 8

# %% [markdown]
# #### Actions
#
# The action space is also continous and includes two features. The first coordinate of an action determines the throttle of the main engine, while the second coordinate specifies the throttle of the lateral boosters.
#
# Given an action `np.array([main, lateral])`, the main engine will be turned off completely if `main < 0` and the throttle scales affinely from 50% to 100% for `0 <= main <= 1` (i.e., the main engine doesn’t work with less than 50% power). Similarly, if `-0.5 < lateral < 0.5`, the lateral boosters will not fire at all. If `lateral < -0.5`, the left booster will fire, and if `lateral > 0.5`, the right booster will fire. Again, the throttle scales affinely from 50% to 100% between -1 and -0.5 (and 0.5 and 1, respectively)

# %%
print(f"Number of action features: {env.action_space.shape[0]}")
# Out:
# Number of action features: 2

# %% [markdown]
# #### Transition and Reward Function
#
# The transition and rewards functions for the environment are not explicitly represented as matrices or tensors. Instead the gym API provides access to the `step` method, which takes in as input an `action` and provides (among other things) an `observation` and `reward`. Also notice the `reset` method, which resets the MDP environment.
#
# The following snippet describes the use of `step` and `reset` methods.

# %%
# Reset the environment
state = env.reset()
# while True:
  # state = next_state
print(f"State: {state}")

# Select a random action to play
action = env.action_space.sample()
print(f"Action: {action}")

# Send this action to the environment to receive the next state and reward
next_state, reward, done, _, _ = env.step(action)
print(f"Next state: {next_state}")
print(f"Reward: {reward}")
# Out:
# State: (array([-0.00272055,  1.4173496 , -0.27558166,  0.2857602 ,  0.00315928,
#         0.06242338,  0.        ,  0.        ], dtype=float32), {})
# Action: [0.8308566  0.36248598]
# Next state: [-0.00546494  1.424218   -0.27744502  0.30525512  0.00614151  0.05965087
#   0.          0.        ]
# Reward: -2.8111205187809842

# %% [markdown]
# -100 is worst reward

# %% [markdown]
# ## Problem 1.1
#
# Next, we will implement the general recipe of the DDPG algorithm to compute the optimal policy for the Lunar Lander.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# #### Actor-Critic Networks
#
# DDPG requires two networks: Actor and Critic. Let us know define these networks.

# %%
class Actor(nn.Module):
  """Actor Network as a Multi-Layer Perceptron."""

  def __init__(self, env, mlp_sizes=[256, 256]):
    """Initialize the Actor Network.

    Args:
        env: An OpenAI Gym environment.
        mlp_sizes: An array of integers. The length of array equals the number
            of hidden layers of the Multi-Layer Perceptron. Each element in the array
            equals the number of nodes in the corresponding layer.
    """
    super().__init__()
    ######## PUT YOUR CODE HERE ########
    # input layer
    self.input_layer = nn.Linear(env.observation_space.shape[0], mlp_sizes[0])

    # hidden layers
    self.hidden_layers = nn.ModuleList()
    for k in range(len(mlp_sizes) - 1):
        self.hidden_layers.append(nn.Linear(mlp_sizes[k], mlp_sizes[k+1]))

    # output layer
    self.output_layer = nn.Linear(mlp_sizes[-1], env.action_space.shape[0])
    ######## PUT YOUR CODE HERE ########

  def forward(self, x):
    """Implements the forward pass of the Actor Network.

    Args:
        x: Input to the Actor Network.

    Returns:
        Output of the Actor Network.
    """
    ######## PUT YOUR CODE HERE ########
    # print(x)
    x = self.input_layer(x)
    # print(x)
    x = torch.relu(x)
    for hl in range(len(self.hidden_layers)):
      x = self.hidden_layers[hl](x)
      # print(hl, x)
      x = torch.relu(x)
    # print(x)
    x = self.output_layer(x)
    # print("preoutput", x)
    x = torch.tanh(x)
    return x
    ######## PUT YOUR CODE HERE ########

# %%
class Critic(nn.Module):
  """Critic Network as a Multi-Layer Perceptron."""

  def __init__(self, env, mlp_sizes=[256, 256]):
    """Initialize the Critic Network.

    Args:
        env: An OpenAI Gym environment.
        mlp_sizes: An array of integers. The length of array equals the number
            of hidden layers of the Multi-Layer Perceptron. Each element in the array
            equals the number of nodes in the corresponding layer.
    """
    super().__init__()

    ######## PUT YOUR CODE HERE ########
    # input layer
    self.input_layer = nn.Linear(env.observation_space.shape[0]+env.action_space.shape[0], mlp_sizes[0])

    # hidden layers
    self.hidden_layers = nn.ModuleList()
    for k in range(len(mlp_sizes) - 1):
        self.hidden_layers.append(nn.Linear(mlp_sizes[k], mlp_sizes[k+1]))

    # output layer
    self.output_layer = nn.Linear(mlp_sizes[-1], 1)
    ######## PUT YOUR CODE HERE ########

  def forward(self, x):
    """Implements the forward pass of the Critic Network.

    Args:
        x: Input to the Critic Network.

    Returns:
        Output of the Critic Network.
    """
    ######## PUT YOUR CODE HERE ########
    # print(x)
    x = self.input_layer(x)
    # print(x)
    x = torch.relu(x)
    for hl in range(len(self.hidden_layers)):
      x = self.hidden_layers[hl](x)
      # print(hl, x)
      x = torch.relu(x)
    # print(x)
    x = self.output_layer(x)
    # print("preoutput", x)
    #x = torch.tanh(x)
    #x = torch.relu(-1*x) * -1 + 200
    return x
    ######## PUT YOUR CODE HERE ########

# %% [markdown]
# #### Replay Buffer
#
# DDPG requires a data structure to store the agent's experiences: Replay Buffer. Let us now define this data structure.

# %%
class ReplayBuffer:
  """A buffer to store agent's experiences."""

  def __init__(self, env, buffer_size):
    """Initialize a buffer to store agent's experiences.

    Args:
        env: An OpenAI Gym environment.
        buffer_size: An integer. The size of the buffer.
    """
    observation_n = env.observation_space.shape[0]
    action_n = env.action_space.shape[0]

    self.buffer_size = buffer_size
    self.observations = np.zeros((self.buffer_size, observation_n), dtype=np.float32)
    self.next_observations = np.zeros((self.buffer_size, observation_n), dtype=np.float32)
    self.actions = np.zeros((self.buffer_size, action_n), dtype=np.float32)
    self.rewards = np.zeros((self.buffer_size,), dtype=np.float32)
    self.dones = np.zeros((self.buffer_size,), dtype=np.float32)

    self.size = 0
    self.pos = 0

  def add(self, observation, next_observation, action, reward, done):
    """Add an experience to the buffer.

    Args:
        observation: the current environment state
        next_observation: the state after executing the action
        action: the action executed in the state
        reward: the reward received after executing the action
        done: Boolean denoting whether the task is completed.
    """
    self.observations[self.pos] = observation
    self.next_observations[self.pos] = next_observation
    self.actions[self.pos] = action
    self.rewards[self.pos] = reward
    self.dones[self.pos] = 1.0 if done else 0.0

    self.pos += 1
    if self.size < self.buffer_size:
      self.size += 1
    if self.pos == self.buffer_size:
      self.pos = 0

  def sample(self, batch_size):
    """Sample a mini-batch of experiences from the replay buffer.
    For ease of implementation, we sample with replacement.

    Args:
        batch_size: An integer. The size of the mini-batch.

    Returns:
        Randomly sampled experiences from the replay buffer.
    """
    indices = np.random.randint(self.size, size=batch_size)
    observations = torch.from_numpy(self.observations[indices])
    next_observations = torch.from_numpy(self.next_observations[indices])
    actions = torch.from_numpy(self.actions[indices])
    rewards = torch.from_numpy(self.rewards[indices])
    dones = torch.from_numpy(self.dones[indices])

    return observations, next_observations, actions, rewards, dones

# %% [markdown]
# #### Exploration schedule
#
# In general, it is useful to explore more initially (when the agent is far from the optimal policy) and less later on in the learning process. To implement this, we can implement a schedule for epsilon.
#
# Similar to the Actor and Critic networks and replay buffer architectures, several choices exist for determining the epsilon schedule. We will use a simple linear scheduler to decay epsilon as agent gains more experience.

# %%
def linear_schedule_for_epsilon(initial_value, final_value, duration, timestep):
  """Implements a linear scheduler for epsilon.

  Args:
      initial_value: (float) Initial value of epsilon.
      final_value: (float) Final value of epsilon.
      duration: (int) Duration over which to decay epsilon from its initial to final value.
      timestep: (int) The current time step.

  Returns:
      Value of epsilon at the given timestep.
  """
  slope = (final_value - initial_value) / duration
  return max(slope * timestep + initial_value, final_value)

# %% [markdown]
# #### Target Networks
# In DDPG, we will update the target network in each iteration of the algorithm. A utility function to update the weights of the target network is provided below.

# %%
def update_weights(src, target, tau=1.0):
  """Utility function to update the target network using Polyak averaging.

  Args:
    src: (target network) source network
    target: (neural network) target network
    tau: (float) Polyak factor
  """

  for target_param, param in zip(target.parameters(), src.parameters()):
    # print("p", target_param.data, param.data)
    # print("s", target_param.data.shape, param.data.shape)
    target_param.data.copy_(
        target_param.data * (1.0 - tau) + param.data * tau
    )

# %% [markdown]
# #### DDPG algorithm
#
# Now that we have all the building blocks, we will implement the DDPG algorithm.
#
# We will use the AgentBase class from Assignment 2 to help us with the implementation.

# %%
class AgentBase:
  def __init__(self, env):
    self.env = env
    self.policy = self.make_policy()
    self.behavior_policy = self.make_behavior_policy()

  def make_policy(self):
    """
    Return a policy function that will be used for evaluation. The policy
    takes observation as input and return action
    """
    raise NotImplementedError

  def make_behavior_policy(self):
    """
    Similar to make_policy, it returns a policy function. But this one used
    for interaction with the environment.
    """
    raise NotImplementedError

  def run_episode(self, episode_policy):
    """
    Generate one episode with the given policy
    """
    episode = []
    done = False
    obs = self.env.reset()[0]
    episode_return = 0
    while not done:
      action = episode_policy(obs)
      next_obs, reward, done, truncated, _ = self.env.step(action)
      done = done or truncated
      episode.append([obs, action, reward, next_obs, done])
      obs = next_obs
      episode_return += reward

    return (episode, episode_return)

  def evaluate(self, num_eval_episodes=1000, plot_title="Evaluation"):
    """Evaluates the agent."""
    list_returns = []
    list_average_returns = []
    average_return = 0
    for episode_idx in range(num_eval_episodes):
      _, episode_return = self.run_episode(self.policy)
      average_return += (1. / (episode_idx+1)) * (episode_return - average_return)
      list_returns.append(episode_return)
      list_average_returns.append(average_return)

    print(f"Average reward {round(average_return, 3)}")
    plt.plot(list_returns,'^',label="Return")
    plt.plot(list_average_returns,'r',label="Average Return")
    plt.ylabel('Return')
    plt.xlabel('Episode#')
    plt.title(plot_title)
    plt.legend()
    plt.ylim(-501, 0.0)
    plt.show()

# %%
class DDPG(AgentBase):
  """Implements DDPG."""

  def __init__(
      self,
      env,
      actor_lr=0.0002,
      critic_lr=0.0003,
      total_timesteps=500000,
      buffer_size=50000,
      warmup_steps=1000,
      batch_size=64,
      tau=0.005,
      noise_std=0.1,
      # actor_lr=0.001,
      # critic_lr=0.001,
      # total_timesteps=500000,
      # buffer_size=100000,
      # warmup_steps=10000,
      # batch_size=100,
      # tau=0.005,
      # noise_std=0.5,
  ):
      """Initializes the Agent.
      Args:
          env: An OpenAI Gym environment.
          actor_lr: (float) Learning rate of actor
          critic_lr: (float) Learning rate of critic
          total_timesteps: (integer) The number of timesteps in training
          buffer_size: (integer) Size of the replay buffer.
          warmup_steps: (integer) Size of data for pre-filling buffer
          batch_size: (integer) Size of the mini batch.
          tau: (float) The amount of update to target actor/critic
          noise_std: (float) Initial noise level for exploration.
      """
      super().__init__(env=env)

      self.gamma = 0.99 # Assume a discount factor of 0.99
      self.env = env
      self.actor_lr = actor_lr
      self.critic_lr = critic_lr
      self.total_timesteps = total_timesteps
      self.buffer_size = buffer_size
      self.warmup_steps = warmup_steps
      self.batch_size = batch_size
      self.tau = tau
      self.noise_std = noise_std

      # Create exploration scheduler
      initial_epsilon = 1.0
      final_epsilon = 0.01
      epsilon_decay_duration = 100000
      self.epsilon_scheduler = lambda current_step: linear_schedule_for_epsilon(
          initial_epsilon, final_epsilon, epsilon_decay_duration, current_step)

      # Create actor and critic
      ######## PUT YOUR CODE HERE ########
      self.actor = Actor(self.env).to(device)
      self.actor_target = Actor(self.env).to(device)
      self.critic = Critic(self.env).to(device)
      self.critic_target = Critic(self.env).to(device)

      # ACTOR TAKES IN STATE GIVES ACTION
      # CRITIC TAKES IN STATE, ACTION GIVES Q VALUE

      print(self.actor)

      ######## PUT YOUR CODE HERE ########

      # Copy weights to target networks
      print("actor update")
      update_weights(self.actor, self.actor_target)
      print("critic update")
      update_weights(self.critic, self.critic_target)

      # Create optimizers
      ######## PUT YOUR CODE HERE ########
      self.actor_optim  = torch.optim.Adam(self.actor.parameters(), lr=self.actor_lr)
      self.critic_optim  = torch.optim.Adam(self.critic.parameters(), lr=self.critic_lr)
      ######## PUT YOUR CODE HERE ########

      # Create replay buffer
      ######## PUT YOUR CODE HERE ########
      self.replay_buffer = ReplayBuffer(self.env, self.buffer_size)
      ######## PUT YOUR CODE HERE ########

      # Create variables for logging
      self.obs = env.reset()[0]
      self.current_step = 0
      self.list_returns = []
      self.list_average_returns = []
      self.average_return = 0.
      self.list_moving_average_returns = []

  @property
  def epsilon(self):
      return self.epsilon_scheduler(self.current_step)

  def make_policy(self):
    def policy_func(observation):
      ######## PUT YOUR CODE HERE ########
      # action according to actor
      optimal_action = self.actor(torch.from_numpy(observation).to(device)) # no argmax here since the value is the action itself
      # Add noise to actions
      optimal_action = torch.clamp(optimal_action, -1, 1)
      return optimal_action.detach().cpu().numpy()
      ######## PUT YOUR CODE HERE ########

    return policy_func

  def make_behavior_policy(self):
    def policy_func(observation):
      ######## PUT YOUR CODE HERE ########
      optimal_action = self.actor(torch.from_numpy(observation).to(device))
      optimal_action += torch.normal(0, self.noise_std, size=optimal_action.shape).to(device)# * self.gamma ** self.current_step//10000
      optimal_action = torch.clamp(optimal_action, -1, 1)
      return optimal_action.detach().cpu().numpy()# if torch.rand((1)) > self.epsilon else env.action_space.sample()
      ######## PUT YOUR CODE HERE ########

    return policy_func

  def update(self):
    if self.current_step > self.warmup_steps:
      ######## PUT YOUR CODE HERE ########
      # Sample a batch
      observations, next_observations, actions, rewards, dones = self.replay_buffer.sample(self.batch_size)
      observations = observations.to(device)
      next_observations = next_observations.to(device)
      actions = actions.to(device)
      rewards = rewards.to(device)
      dones = dones.to(device)

      # print(torch.cat((observations, actions), 1).shape)
      # print("critic output", self.critic(torch.cat((observations, self.actor(observations)), 1)).shape)
      # print("obs", observations.shape)
      # print("acts", actions.shape)
      # print("nextobs", next_observations.shape)
      # print("rewards", rewards.shape)
      # print("dones", dones.shape)

      # Get target values
      y_i = rewards.to(device) + (1-dones).to(device) * self.critic_target(torch.cat((next_observations.to(device), self.actor_target(next_observations)), 1).to(device)).squeeze() * self.gamma
      # print(y_i.shape)

      # Decay learning rate
      # NotImplemented

      # Update critic
      # print(self.critic(torch.cat((observations, actions), 1)).squeeze().shape)
      self.critic.train()
      self.critic_optim.zero_grad()
      loss_fn = nn.MSELoss()
      critic_loss = loss_fn(self.critic(torch.cat((observations, actions), 1).to(device)).squeeze(), y_i)
      critic_loss.backward()
      self.critic_optim.step()

      # Update actor
      self.actor.train()
      self.actor_optim.zero_grad()
      actor_loss = -1 * self.critic(torch.cat((observations, self.actor(observations)), 1).to(device)).squeeze()
      # print(actor_loss)
      actor_loss.mean().backward()
      self.actor_optim.step()

      ######## PUT YOUR CODE HERE ########

    # print(self.actor, self.actor_target)

    # Update Target Network
    update_weights(self.actor, self.actor_target, self.tau)
    update_weights(self.critic, self.critic_target, self.tau)


  def train(self, make_plot=False, show_instant=0):
    episode_return = 0.
    while self.current_step < self.total_timesteps:
      # print(self.current_step)

      # Interact with env
      action = self.behavior_policy(self.obs)
      next_obs, reward, done, truncated, info = self.env.step(action)
      episode_return += reward
      done = done or truncated

      if done:
        # Store the return for evaluation
        self.list_returns.append(episode_return)
        episode_return = 0.
        self.average_return = np.mean(np.asarray(self.list_returns))
        self.list_average_returns.append(self.average_return)

        if len(self.list_average_returns) > 20:
          self.list_moving_average_returns.append(np.mean(self.list_returns[-20:]))
        else:
          self.list_moving_average_returns.append(self.average_return)

      # Save data into buffer
      self.replay_buffer.add(self.obs, next_obs, action, reward, done)

      # Update networks
      self.update()

      # Prepare for next iteration
      if done:
        self.obs = env.reset()[0]
      else:
        self.obs = next_obs

      if self.current_step % 1000 == 999:
        print(f"Timestep: {self.current_step+1}, episode reward (moving average, 20 episodes): {round(self.list_moving_average_returns[-1],2)}")
      self.current_step += 1

    if make_plot:
      # plt.plot(self.list_returns,'^',label="Return")
      # plt.plot(self.list_average_returns,'r',label="Average Return (all episodes)")
      # plt.plot(self.list_moving_average_returns,'b',label="Average Return (last 20 episodes)")
      # plt.ylabel('Return')
      # plt.xlabel('Episode#')
      # plt.title('Performance during training')
      # plt.ylim(-501, 300)
      # plt.legend()
      # plt.show()
      self.make_plot(show_instant)

  def make_plot(self, show_returns=1, show_avgret=1, show_movavg=1, default_scheme=1, listret_color='^', avgret_color='r', movavg_color='b', show_instant=0, model_label=""):
    if show_returns:
      plt.plot(self.list_returns,'^' if default_scheme else listret_color,label="Return" + model_label)
    if show_avgret:
      plt.plot(self.list_average_returns,'r' if default_scheme else avgret_color,label="Average Return (all episodes)" + model_label)
    if show_movavg:
      plt.plot(self.list_moving_average_returns,'b' if default_scheme else movavg_color,label="Average Return (last 20 episodes), " + model_label)
    plt.ylabel('Return')
    plt.xlabel('Episode#')
    plt.title('Performance during training')
    # plt.ylim(-501, 0.0)
    plt.legend()
    if show_instant:
      plt.show()

  def copy_params(self, other_DDPG):



    self.epsilon_scheduler = other_DDPG.epsilon_scheduler

    # Create actor and critic
    ######## PUT YOUR CODE HERE ########
    self.actor = other_DDPG.actor
    self.actor_target = other_DDPG.actor_target
    self.critic = other_DDPG.critic
    self.critic_target = other_DDPG.critic_target


    # Create optimizers
    ######## PUT YOUR CODE HERE ########
    self.actor_optim  = other_DDPG.actor_optim
    self.critic_optim  = other_DDPG.critic_optim
    ######## PUT YOUR CODE HERE ########

    # Create replay buffer
    ######## PUT YOUR CODE HERE ########
    self.replay_buffer = other_DDPG.replay_buffer
    ######## PUT YOUR CODE HERE ########

    # Create variables for logging
    self.obs = other_DDPG.obs
    self.current_step = other_DDPG.current_step
    self.list_returns = other_DDPG.list_returns
    self.list_average_returns = other_DDPG.list_average_returns
    self.average_return = other_DDPG.average_return
    self.list_moving_average_returns = other_DDPG.list_moving_average_returns

# %% [markdown]
# #### Training the Agent
#
# Having implemented the agent, now we will train it using the default hyperparameters provided in the class definition and observe its performance.

# %%
env = gym.make("LunarLanderContinuous-v2")

# %%
agent_001 = DDPG(env)
agent_001.train(make_plot=True)
# Out:
# Actor(
#   (input_layer): Linear(in_features=8, out_features=256, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (output_layer): Linear(in_features=256, out_features=2, bias=True)
# )
# actor update
# critic update
# Timestep: 1000, episode reward (moving average, 20 episodes): -126.49
# Timestep: 2000, episode reward (moving average, 20 episodes): -260.65
# Timestep: 3000, episode reward (moving average, 20 episodes): -284.07
# Timestep: 4000, episode reward (moving average, 20 episodes): -350.27
# Timestep: 5000, episode reward (moving average, 20 episodes): -354.95
# Timestep: 6000, episode reward (moving average, 20 episodes): -248.27
# Timestep: 7000, episode reward (moving average, 20 episodes): -229.27
# Timestep: 8000, episode reward (moving average, 20 episodes): -199.2
# Timestep: 9000, episode reward (moving average, 20 episodes): -194.79
# Timestep: 10000, episode reward (moving average, 20 episodes): -161.37
# Timestep: 11000, episode reward (moving average, 20 episodes): -140.95
# Timestep: 12000, episode reward (moving average, 20 episodes): -134.12
# Timestep: 13000, episode reward (moving average, 20 episodes): -147.18
# Timestep: 14000, episode reward (moving average, 20 episodes): -137.38
# Timestep: 15000, episode reward (moving average, 20 episodes): -115.67
# Timestep: 16000, episode reward (moving average, 20 episodes): -119.55
# Timestep: 17000, episode reward (moving average, 20 episodes): -129.21
# Timestep: 18000, episode reward (moving average, 20 episodes): -123.07
# Timestep: 19000, episode reward (moving average, 20 episodes): -180.3
# Timestep: 20000, episode reward (moving average, 20 episodes): -213.18
# Timestep: 21000, episode reward (moving average, 20 episodes): -259.03
# Timestep: 22000, episode reward (moving average, 20 episodes): -266.82
# Timestep: 23000, episode reward (moving average, 20 episodes): -250.58
# Timestep: 24000, episode reward (moving average, 20 episodes): -236.81
# Timestep: 25000, episode reward (moving average, 20 episodes): -252.72
# Timestep: 26000, episode reward (moving average, 20 episodes): -217.08
# Timestep: 27000, episode reward (moving average, 20 episodes): -202.57
# Timestep: 28000, episode reward (moving average, 20 episodes): -204.24
# Timestep: 29000, episode reward (moving average, 20 episodes): -213.84
# Timestep: 30000, episode reward (moving average, 20 episodes): -193.13
# Timestep: 31000, episode reward (moving average, 20 episodes): -167.09
# Timestep: 32000, episode reward (moving average, 20 episodes): -162.0
# Timestep: 33000, episode reward (moving average, 20 episodes): -141.14
# Timestep: 34000, episode reward (moving average, 20 episodes): -145.8
# Timestep: 35000, episode reward (moving average, 20 episodes): -136.09
# Timestep: 36000, episode reward (moving average, 20 episodes): -138.79
# Timestep: 37000, episode reward (moving average, 20 episodes): -138.5
# Timestep: 38000, episode reward (moving average, 20 episodes): -126.12
# Timestep: 39000, episode reward (moving average, 20 episodes): -123.15
# Timestep: 40000, episode reward (moving average, 20 episodes): -107.69
# Timestep: 487000, episode reward (moving average, 20 episodes): 205.22
# Timestep: 488000, episode reward (moving average, 20 episodes): 177.45
# Timestep: 489000, episode reward (moving average, 20 episodes): 138.31
# Timestep: 490000, episode reward (moving average, 20 episodes): 137.11
# Timestep: 491000, episode reward (moving average, 20 episodes): 126.34
# Timestep: 492000, episode reward (moving average, 20 episodes): 112.38
# Timestep: 493000, episode reward (moving average, 20 episodes): 50.31
# Timestep: 494000, episode reward (moving average, 20 episodes): 87.51
# Timestep: 495000, episode reward (moving average, 20 episodes): 51.2
# Timestep: 496000, episode reward (moving average, 20 episodes): 93.48
# Timestep: 497000, episode reward (moving average, 20 episodes): 104.07
# Timestep: 498000, episode reward (moving average, 20 episodes): 106.06
# Timestep: 499000, episode reward (moving average, 20 episodes): 101.14
# Timestep: 500000, episode reward (moving average, 20 episodes): 135.18

# %% [markdown]
# ## Problem 1.2
#
# The performance of RL algorithms typically varies across runs. Report results of five runs of your algorithm and summarize the performance in a single plot.

# %%
agent_001.evaluate()
# Out:
# Average reward 173.818

# %%
######## PUT YOUR CODE HERE ########
agent_one = DDPG(env, total_timesteps=500000)
agent_one.train()
agent_two = DDPG(env, total_timesteps=500000)
agent_two.train()
agent_three = DDPG(env, total_timesteps=500000)
agent_three.train()
agent_four = DDPG(env, total_timesteps=500000)
agent_four.train()
agent_five = DDPG(env, total_timesteps=500000)
agent_five.train()
######## PUT YOUR CODE HERE ########
# Out:
# Actor(
#   (input_layer): Linear(in_features=8, out_features=256, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (output_layer): Linear(in_features=256, out_features=2, bias=True)
# )
# actor update
# critic update
# Timestep: 1000, episode reward (moving average, 20 episodes): -203.66
# Timestep: 2000, episode reward (moving average, 20 episodes): -219.44
# Timestep: 3000, episode reward (moving average, 20 episodes): -225.29
# Timestep: 4000, episode reward (moving average, 20 episodes): -226.33
# Timestep: 5000, episode reward (moving average, 20 episodes): -235.24
# Timestep: 6000, episode reward (moving average, 20 episodes): -235.03
# Timestep: 7000, episode reward (moving average, 20 episodes): -242.67
# Timestep: 8000, episode reward (moving average, 20 episodes): -195.06
# Timestep: 9000, episode reward (moving average, 20 episodes): -174.02
# Timestep: 10000, episode reward (moving average, 20 episodes): -120.83
# Timestep: 11000, episode reward (moving average, 20 episodes): -106.67
# Timestep: 12000, episode reward (moving average, 20 episodes): -90.79
# Timestep: 13000, episode reward (moving average, 20 episodes): -69.58
# Timestep: 14000, episode reward (moving average, 20 episodes): -77.25
# Timestep: 15000, episode reward (moving average, 20 episodes): -84.29
# Timestep: 16000, episode reward (moving average, 20 episodes): -84.57
# Timestep: 17000, episode reward (moving average, 20 episodes): -79.94
# Timestep: 18000, episode reward (moving average, 20 episodes): -111.61
# Timestep: 19000, episode reward (moving average, 20 episodes): -99.83
# Timestep: 20000, episode reward (moving average, 20 episodes): -89.65
# Timestep: 21000, episode reward (moving average, 20 episodes): -79.47
# Timestep: 22000, episode reward (moving average, 20 episodes): -79.95
# Timestep: 23000, episode reward (moving average, 20 episodes): -94.44
# Timestep: 214000, episode reward (moving average, 20 episodes): 144.53
# Timestep: 215000, episode reward (moving average, 20 episodes): 152.68
# Timestep: 216000, episode reward (moving average, 20 episodes): 153.47
# Timestep: 217000, episode reward (moving average, 20 episodes): 164.32
# Timestep: 218000, episode reward (moving average, 20 episodes): 170.81
# Timestep: 219000, episode reward (moving average, 20 episodes): 176.37
# Timestep: 220000, episode reward (moving average, 20 episodes): 121.38
# Timestep: 221000, episode reward (moving average, 20 episodes): 112.9
# Timestep: 222000, episode reward (moving average, 20 episodes): 87.82
# Timestep: 223000, episode reward (moving average, 20 episodes): 81.84
# Timestep: 224000, episode reward (moving average, 20 episodes): 54.87
# Timestep: 225000, episode reward (moving average, 20 episodes): 63.84
# Timestep: 226000, episode reward (moving average, 20 episodes): 57.48
# Timestep: 227000, episode reward (moving average, 20 episodes): 59.85
# Timestep: 228000, episode reward (moving average, 20 episodes): 47.16
# Timestep: 229000, episode reward (moving average, 20 episodes): 63.81
# Timestep: 230000, episode reward (moving average, 20 episodes): 89.43
# Timestep: 231000, episode reward (moving average, 20 episodes): 93.88
# Timestep: 232000, episode reward (moving average, 20 episodes): 84.22
# Timestep: 233000, episode reward (moving average, 20 episodes): 78.7
# Timestep: 234000, episode reward (moving average, 20 episodes): 74.93
# Timestep: 235000, episode reward (moving average, 20 episodes): 62.56
# Timestep: 236000, episode reward (moving average, 20 episodes): 63.3
# Timestep: 237000, episode reward (moving average, 20 episodes): 63.63
# Timestep: 238000, episode reward (moving average, 20 episodes): 52.55
# Timestep: 239000, episode reward (moving average, 20 episodes): 74.95
# Timestep: 240000, episode reward (moving average, 20 episodes): 111.34
# Timestep: 241000, episode reward (moving average, 20 episodes): 123.3
# Timestep: 242000, episode reward (moving average, 20 episodes): 110.04
# Timestep: 243000, episode reward (moving average, 20 episodes): 128.62
# Timestep: 244000, episode reward (moving average, 20 episodes): 135.85
# Timestep: 245000, episode reward (moving average, 20 episodes): 126.0
# Timestep: 246000, episode reward (moving average, 20 episodes): 111.58
# Timestep: 247000, episode reward (moving average, 20 episodes): 124.56
# Timestep: 248000, episode reward (moving average, 20 episodes): 110.97
# Timestep: 249000, episode reward (moving average, 20 episodes): 105.49

# %%
agent_one.make_plot(show_returns=0, show_avgret=0, show_movavg=1, default_scheme=0, listret_color='^', avgret_color='r', movavg_color='r', show_instant=0, model_label=" AgentOne")
agent_two.make_plot(show_returns=0, show_avgret=0, show_movavg=1, default_scheme=0, listret_color='^', avgret_color='g', movavg_color='g', show_instant=0, model_label=" AgentTwo")
agent_three.make_plot(show_returns=0, show_avgret=0, show_movavg=1, default_scheme=0, listret_color='^', avgret_color='b', movavg_color='b', show_instant=0, model_label=" AgentThree")
agent_four.make_plot(show_returns=0, show_avgret=0, show_movavg=1, default_scheme=0, listret_color='^', avgret_color='c', movavg_color='c', show_instant=0, model_label=" AgentFour")
agent_five.make_plot(show_returns=0, show_avgret=0, show_movavg=1, default_scheme=0, listret_color='^', avgret_color='y', movavg_color='y', show_instant=0, model_label=" AgentFive")

# %% [markdown]
# ## Problem 1.3
#
# Select any one hyperparameter of the algorithm and study its effect on the agent's performance.
# You should try at least five different values of this hyperparameter and report on the observed performance. In a single plot, show the performance of the agent for different values of hyperparameter.

# %%
######## PUT YOUR CODE HERE ########
# we want to vary lr -- we vary both here since we want to match their learning speed -- mismatching would be another hyperparam to test tbh
base_actor_lr = agent_001.actor_lr
base_critic_lr = agent_001.critic_lr
agent_a = DDPG(env, total_timesteps=500000, actor_lr=base_actor_lr/10, critic_lr=base_critic_lr/10)
agent_a.train()
agent_b = DDPG(env, total_timesteps=500000, actor_lr=base_actor_lr/2, critic_lr=base_critic_lr/2)
agent_b.train()
agent_c = DDPG(env, total_timesteps=500000)
agent_c.train()
agent_d = DDPG(env, total_timesteps=500000, actor_lr=base_actor_lr*2, critic_lr=base_critic_lr*2)
agent_d.train()
agent_e = DDPG(env, total_timesteps=500000, actor_lr=base_actor_lr*10, critic_lr=base_critic_lr*10)
agent_e.train()
######## PUT YOUR CODE HERE ########

# %%
agent_a.make_plot(show_returns=0, show_avgret=0, show_movavg=1, default_scheme=0, listret_color='^', avgret_color='r', movavg_color='r', show_instant=0, model_label=" 1/10 lr")
agent_b.make_plot(show_returns=0, show_avgret=0, show_movavg=1, default_scheme=0, listret_color='^', avgret_color='g', movavg_color='g', show_instant=0, model_label=" 1/2 lr")
agent_c.make_plot(show_returns=0, show_avgret=0, show_movavg=1, default_scheme=0, listret_color='^', avgret_color='b', movavg_color='b', show_instant=0, model_label=" base lr")
agent_d.make_plot(show_returns=0, show_avgret=0, show_movavg=1, default_scheme=0, listret_color='^', avgret_color='c', movavg_color='c', show_instant=0, model_label=" 2x lr")
agent_e.make_plot(show_returns=0, show_avgret=0, show_movavg=1, default_scheme=0, listret_color='^', avgret_color='y', movavg_color='y', show_instant=0, model_label=" 10x lr")

# %% [markdown]
# ## Problem 1.4
#
# While applying RL in real world, you may consider the use of off-the-shelf implementation of RL algorithms. The package [Stable Baselines 3](stable-baselines3.readthedocs.io/) aims to provide a set of reliable implementations of RL algorithms in PyTorch.
#
# Familiarize yourself with this package and use its implementation of DDPG to learn the optimal policy for the Lunar Lander environment.

# %%
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnNoModelImprovement
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
######## PUT YOUR CODE HERE ########
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=agent_001.noise_std * np.ones(n_actions))

# Variables for tracking rewards
window_size = 20

sb3_model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1)
sb3_model.learn(total_timesteps=500000, log_interval=20)

######## PUT YOUR CODE HERE ########
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.9     |
# |    ep_rew_mean     | -195     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 133      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1438     |
# | train/             |          |
# |    actor_loss      | 8.66     |
# |    critic_loss     | 16.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1362     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 138      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 5726     |
# | train/             |          |
# |    actor_loss      | -22.2    |
# |    critic_loss     | 45.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5601     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | -203     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 137      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 8384     |
# | train/             |          |
# |    actor_loss      | -32.8    |
# |    critic_loss     | 56.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8316     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 138      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 9837     |
# | train/             |          |
# |    actor_loss      | -37.2    |
# |    critic_loss     | 54.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9681     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 148      |
# |    ep_rew_mean     | -175     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 140      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 14792    |
# | train/             |          |
# |    actor_loss      | -47.1    |
# |    critic_loss     | 41.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14494    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 195      |
# |    ep_rew_mean     | -149     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 142      |
# |    time_elapsed    | 146      |
# |    total_timesteps | 20949    |
# | train/             |          |
# |    actor_loss      | -60.5    |
# |    critic_loss     | 30       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20316    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 140      |
# |    time_elapsed    | 178      |
# |    total_timesteps | 25074    |
# | train/             |          |
# |    actor_loss      | -69.4    |
# |    critic_loss     | 40.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24849    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | -100     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 139      |
# |    time_elapsed    | 223      |
# |    total_timesteps | 31128    |
# | train/             |          |
# |    actor_loss      | -83.1    |
# |    critic_loss     | 43.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31028    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 284      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 139      |
# |    time_elapsed    | 273      |
# |    total_timesteps | 38188    |
# | train/             |          |
# |    actor_loss      | -97.3    |
# |    critic_loss     | 49       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 38088    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 276      |
# |    ep_rew_mean     | -91.9    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 139      |
# |    time_elapsed    | 303      |
# |    total_timesteps | 42439    |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 55.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 42334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 247      |
# |    ep_rew_mean     | -90.7    |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 139      |
# |    time_elapsed    | 326      |
# |    total_timesteps | 45654    |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 61.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 45506    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 235      |
# |    ep_rew_mean     | -120     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 139      |
# |    time_elapsed    | 347      |
# |    total_timesteps | 48590    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 54.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 48428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 139      |
# |    time_elapsed    | 364      |
# |    total_timesteps | 50820    |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 56.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 50728    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 148      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 139      |
# |    time_elapsed    | 379      |
# |    total_timesteps | 53027    |
# | train/             |          |
# |    actor_loss      | -137     |
# |    critic_loss     | 69.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 52879    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -99.8    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 139      |
# |    time_elapsed    | 401      |
# |    total_timesteps | 56033    |
# | train/             |          |
# |    actor_loss      | -139     |
# |    critic_loss     | 60.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55947    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 158      |
# |    ep_rew_mean     | -90.4    |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 139      |
# |    time_elapsed    | 439      |
# |    total_timesteps | 61485    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 71.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 61239    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 181      |
# |    ep_rew_mean     | -65.1    |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 139      |
# |    time_elapsed    | 477      |
# |    total_timesteps | 66662    |
# | train/             |          |
# |    actor_loss      | -152     |
# |    critic_loss     | 88.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 66384    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 235      |
# |    ep_rew_mean     | -50.4    |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 139      |
# |    time_elapsed    | 532      |
# |    total_timesteps | 74273    |
# | train/             |          |
# |    actor_loss      | -160     |
# |    critic_loss     | 92       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 74075    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 296      |
# |    ep_rew_mean     | -20.7    |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 139      |
# |    time_elapsed    | 591      |
# |    total_timesteps | 82651    |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 87.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82241    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 342      |
# |    ep_rew_mean     | 4.35     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 140      |
# |    time_elapsed    | 642      |
# |    total_timesteps | 90232    |
# | train/             |          |
# |    actor_loss      | -178     |
# |    critic_loss     | 106      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 89232    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 370      |
# |    ep_rew_mean     | 6.47     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 139      |
# |    time_elapsed    | 705      |
# |    total_timesteps | 98464    |
# | train/             |          |
# |    actor_loss      | -183     |
# |    critic_loss     | 78.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98118    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 428      |
# |    ep_rew_mean     | 23.2     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 140      |
# |    time_elapsed    | 781      |
# |    total_timesteps | 109495   |
# | train/             |          |
# |    actor_loss      | -179     |
# |    critic_loss     | 72.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 108743   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 439      |
# |    ep_rew_mean     | 9.04     |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 140      |
# |    time_elapsed    | 841      |
# |    total_timesteps | 118162   |
# | train/             |          |
# |    actor_loss      | -173     |
# |    critic_loss     | 76.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 117162   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 462      |
# |    ep_rew_mean     | -6.4     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 140      |
# |    time_elapsed    | 918      |
# |    total_timesteps | 128849   |
# | train/             |          |
# |    actor_loss      | -166     |
# |    critic_loss     | 58.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 127849   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 459      |
# |    ep_rew_mean     | -46      |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 139      |
# |    time_elapsed    | 975      |
# |    total_timesteps | 136147   |
# | train/             |          |
# |    actor_loss      | -159     |
# |    critic_loss     | 56.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 135900   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 432      |
# |    ep_rew_mean     | -70.5    |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 139      |
# |    time_elapsed    | 1014     |
# |    total_timesteps | 141705   |
# | train/             |          |
# |    actor_loss      | -156     |
# |    critic_loss     | 64       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 141287   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 389      |
# |    ep_rew_mean     | -80.6    |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 139      |
# |    time_elapsed    | 1062     |
# |    total_timesteps | 148367   |
# | train/             |          |
# |    actor_loss      | -153     |
# |    critic_loss     | 55.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 148005   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -54.2    |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 139      |
# |    time_elapsed    | 1132     |
# |    total_timesteps | 158120   |
# | train/             |          |
# |    actor_loss      | -149     |
# |    critic_loss     | 58.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 157995   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 359      |
# |    ep_rew_mean     | -27.6    |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 139      |
# |    time_elapsed    | 1178     |
# |    total_timesteps | 164712   |
# | train/             |          |
# |    actor_loss      | -148     |
# |    critic_loss     | 60.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 164423   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 337      |
# |    ep_rew_mean     | 42.5     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 139      |
# |    time_elapsed    | 1213     |
# |    total_timesteps | 169878   |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 58.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 169657   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 323      |
# |    ep_rew_mean     | 84.1     |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 140      |
# |    time_elapsed    | 1242     |
# |    total_timesteps | 174042   |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 46.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173832   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | 77       |
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 140      |
# |    time_elapsed    | 1283     |
# |    total_timesteps | 179764   |
# | train/             |          |
# |    actor_loss      | -139     |
# |    critic_loss     | 68.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179630   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 267      |
# |    ep_rew_mean     | 58.2     |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 140      |
# |    time_elapsed    | 1319     |
# |    total_timesteps | 184866   |
# | train/             |          |
# |    actor_loss      | -138     |
# |    critic_loss     | 55.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 184748   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 277      |
# |    ep_rew_mean     | 48.8     |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 140      |
# |    time_elapsed    | 1371     |
# |    total_timesteps | 192368   |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 48.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 192136   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | 13.4     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 140      |
# |    time_elapsed    | 1418     |
# |    total_timesteps | 198866   |
# | train/             |          |
# |    actor_loss      | -135     |
# |    critic_loss     | 49.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198771   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 5.56     |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 140      |
# |    time_elapsed    | 1455     |
# |    total_timesteps | 204094   |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 46.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 203998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 286      |
# |    ep_rew_mean     | 30       |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 140      |
# |    time_elapsed    | 1481     |
# |    total_timesteps | 208327   |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 52.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 207579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 61.7     |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 140      |
# |    time_elapsed    | 1534     |
# |    total_timesteps | 215311   |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 49.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 215205   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 346      |
# |    ep_rew_mean     | 78.4     |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 140      |
# |    time_elapsed    | 1610     |
# |    total_timesteps | 226994   |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 46.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 225994   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 378      |
# |    ep_rew_mean     | 86.3     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 140      |
# |    time_elapsed    | 1682     |
# |    total_timesteps | 236705   |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 56.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 236267   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 419      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 820      |
# |    fps             | 140      |
# |    time_elapsed    | 1749     |
# |    total_timesteps | 245960   |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 42.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 245664   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 472      |
# |    ep_rew_mean     | 121      |
# | time/              |          |
# |    episodes        | 840      |
# |    fps             | 140      |
# |    time_elapsed    | 1816     |
# |    total_timesteps | 255525   |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 49.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 255214   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 475      |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 860      |
# |    fps             | 140      |
# |    time_elapsed    | 1868     |
# |    total_timesteps | 262763   |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 40.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 262501   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 413      |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 880      |
# |    fps             | 140      |
# |    time_elapsed    | 1907     |
# |    total_timesteps | 268291   |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 38.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 268151   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 397      |
# |    ep_rew_mean     | 118      |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 140      |
# |    time_elapsed    | 1963     |
# |    total_timesteps | 276445   |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 43.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 276072   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 368      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 920      |
# |    fps             | 140      |
# |    time_elapsed    | 2008     |
# |    total_timesteps | 282793   |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 39.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 282564   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 322      |
# |    ep_rew_mean     | 120      |
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 140      |
# |    time_elapsed    | 2043     |
# |    total_timesteps | 287707   |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 58.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 287529   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 309      |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    episodes        | 960      |
# |    fps             | 141      |
# |    time_elapsed    | 2082     |
# |    total_timesteps | 293655   |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 50.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 293056   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 306      |
# |    ep_rew_mean     | 139      |
# | time/              |          |
# |    episodes        | 980      |
# |    fps             | 140      |
# |    time_elapsed    | 2122     |
# |    total_timesteps | 298930   |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 61.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298793   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 276      |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 140      |
# |    time_elapsed    | 2157     |
# |    total_timesteps | 304061   |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 42.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 303805   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 269      |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 1020     |
# |    fps             | 140      |
# |    time_elapsed    | 2198     |
# |    total_timesteps | 309732   |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 42.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 309602   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 1040     |
# |    fps             | 140      |
# |    time_elapsed    | 2249     |
# |    total_timesteps | 317044   |
# | train/             |          |
# |    actor_loss      | -124     |
# |    critic_loss     | 75.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 316934   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 282      |
# |    ep_rew_mean     | 182      |
# | time/              |          |
# |    episodes        | 1060     |
# |    fps             | 141      |
# |    time_elapsed    | 2282     |
# |    total_timesteps | 321891   |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 49.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 321653   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    episodes        | 1080     |
# |    fps             | 140      |
# |    time_elapsed    | 2315     |
# |    total_timesteps | 326460   |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 49.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 326356   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 326      |
# |    ep_rew_mean     | 144      |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 141      |
# |    time_elapsed    | 2386     |
# |    total_timesteps | 336697   |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 38.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 336488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 313      |
# |    ep_rew_mean     | 125      |
# | time/              |          |
# |    episodes        | 1120     |
# |    fps             | 141      |
# |    time_elapsed    | 2417     |
# |    total_timesteps | 341067   |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 34.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340829   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 1140     |
# |    fps             | 141      |
# |    time_elapsed    | 2457     |
# |    total_timesteps | 346798   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 36.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 346595   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 91.8     |
# | time/              |          |
# |    episodes        | 1160     |
# |    fps             | 141      |
# |    time_elapsed    | 2500     |
# |    total_timesteps | 352932   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 40.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 352690   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 330      |
# |    ep_rew_mean     | 90.2     |
# | time/              |          |
# |    episodes        | 1180     |
# |    fps             | 141      |
# |    time_elapsed    | 2543     |
# |    total_timesteps | 359413   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 44.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 358756   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 302      |
# |    ep_rew_mean     | 89.8     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 141      |
# |    time_elapsed    | 2597     |
# |    total_timesteps | 366941   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 39.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 366586   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 371      |
# |    ep_rew_mean     | 88.7     |
# | time/              |          |
# |    episodes        | 1220     |
# |    fps             | 141      |
# |    time_elapsed    | 2672     |
# |    total_timesteps | 378209   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 37.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 377209   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 399      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 1240     |
# |    fps             | 141      |
# |    time_elapsed    | 2737     |
# |    total_timesteps | 386713   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 36.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 386536   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 433      |
# |    ep_rew_mean     | 120      |
# | time/              |          |
# |    episodes        | 1260     |
# |    fps             | 141      |
# |    time_elapsed    | 2803     |
# |    total_timesteps | 396233   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 38.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 395910   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 437      |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 1280     |
# |    fps             | 141      |
# |    time_elapsed    | 2851     |
# |    total_timesteps | 403137   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 39       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 402815   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 454      |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 141      |
# |    time_elapsed    | 2916     |
# |    total_timesteps | 412333   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 33.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 412011   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 414      |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 1320     |
# |    fps             | 141      |
# |    time_elapsed    | 2968     |
# |    total_timesteps | 419655   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 29.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 419450   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 396      |
# |    ep_rew_mean     | 231      |
# | time/              |          |
# |    episodes        | 1340     |
# |    fps             | 141      |
# |    time_elapsed    | 3013     |
# |    total_timesteps | 426288   |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 25.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 426067   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 357      |
# |    ep_rew_mean     | 238      |
# | time/              |          |
# |    episodes        | 1360     |
# |    fps             | 141      |
# |    time_elapsed    | 3048     |
# |    total_timesteps | 431899   |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 31       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 430899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 346      |
# |    ep_rew_mean     | 241      |
# | time/              |          |
# |    episodes        | 1380     |
# |    fps             | 141      |
# |    time_elapsed    | 3092     |
# |    total_timesteps | 437761   |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 29.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 437371   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 313      |
# |    ep_rew_mean     | 250      |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 141      |
# |    time_elapsed    | 3134     |
# |    total_timesteps | 443660   |
# | train/             |          |
# |    actor_loss      | -99.6    |
# |    critic_loss     | 28.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 443491   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | 250      |
# | time/              |          |
# |    episodes        | 1420     |
# |    fps             | 141      |
# |    time_elapsed    | 3171     |
# |    total_timesteps | 448907   |
# | train/             |          |
# |    actor_loss      | -99.3    |
# |    critic_loss     | 24.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 448727   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 279      |
# |    ep_rew_mean     | 251      |
# | time/              |          |
# |    episodes        | 1440     |
# |    fps             | 141      |
# |    time_elapsed    | 3206     |
# |    total_timesteps | 454178   |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 27.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 453982   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 284      |
# |    ep_rew_mean     | 248      |
# | time/              |          |
# |    episodes        | 1460     |
# |    fps             | 141      |
# |    time_elapsed    | 3248     |
# |    total_timesteps | 460313   |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 24.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 459915   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 276      |
# |    ep_rew_mean     | 254      |
# | time/              |          |
# |    episodes        | 1480     |
# |    fps             | 141      |
# |    time_elapsed    | 3284     |
# |    total_timesteps | 465349   |
# | train/             |          |
# |    actor_loss      | -99.4    |
# |    critic_loss     | 22.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 465090   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 277      |
# |    ep_rew_mean     | 257      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 141      |
# |    time_elapsed    | 3326     |
# |    total_timesteps | 471395   |
# | train/             |          |
# |    actor_loss      | -99.2    |
# |    critic_loss     | 25.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 471149   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 296      |
# |    ep_rew_mean     | 250      |
# | time/              |          |
# |    episodes        | 1520     |
# |    fps             | 141      |
# |    time_elapsed    | 3370     |
# |    total_timesteps | 478468   |
# | train/             |          |
# |    actor_loss      | -99.8    |
# |    critic_loss     | 15.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 477468   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 320      |
# |    ep_rew_mean     | 245      |
# | time/              |          |
# |    episodes        | 1540     |
# |    fps             | 141      |
# |    time_elapsed    | 3424     |
# |    total_timesteps | 486186   |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 26       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 485186   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 312      |
# |    ep_rew_mean     | 234      |
# | time/              |          |
# |    episodes        | 1560     |
# |    fps             | 141      |
# |    time_elapsed    | 3465     |
# |    total_timesteps | 491507   |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 29.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 491259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 306      |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    episodes        | 1580     |
# |    fps             | 141      |
# |    time_elapsed    | 3496     |
# |    total_timesteps | 495942   |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 25.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495732   |
# ---------------------------------
# 19 reward =  298.32933293175756 , average =  235.84627703639916
# 20 reward =  285.17826607398445 , average =  236.85330515414245
# 21 reward =  264.48500476704794 , average =  235.91250896572427
# 22 reward =  263.528355072794 , average =  237.13936389787682
# 23 reward =  260.7732186939757 , average =  239.55170027930217
# 24 reward =  261.9201871697608 , average =  239.49948693459837
# 25 reward =  235.4197398693251 , average =  237.23967689576634
# 26 reward =  248.41704923879752 , average =  236.20375323401672
# 27 reward =  207.57502838721803 , average =  231.68450050792018
# 28 reward =  288.34339162043386 , average =  234.9766972528173
# 29 reward =  224.45391125671597 , average =  232.35037840095032
# 30 reward =  260.6683171416214 , average =  230.09762072383174
# 31 reward =  296.96623976950275 , average =  228.86113961839106
# 32 reward =  227.9930141057019 , average =  233.48407402539888
# 33 reward =  306.9659373573134 , average =  233.86659956881135
# 34 reward =  249.23027179261192 , average =  233.32791663393192
# 35 reward =  239.73898971237006 , average =  237.80299821624197
# 36 reward =  248.60771808033917 , average =  257.0582915766468
# 37 reward =  283.63720418661285 , average =  259.68728441166536
# 38 reward =  264.0304474844993 , average =  260.8130812356192
# 39 reward =  270.42213125033027 , average =  259.4177211515478
# 40 reward =  275.69031407788873 , average =  258.943323551743
# 41 reward =  300.69545814107835 , average =  260.75384622044464
# 42 reward =  262.05634657452987 , average =  260.68024579553133
# 43 reward =  235.92517402361221 , average =  259.4378435620132
# 44 reward =  235.22976777008455 , average =  258.1033225920294
# 45 reward =  231.96800995236165 , average =  257.93073609618125
# 46 reward =  273.04330647780284 , average =  259.1620489581315
# 47 reward =  296.03273205838536 , average =  263.5849341416898
# 48 reward =  263.3405171937022 , average =  262.3347904203532
# 49 reward =  201.47551370755662 , average =  261.18587054289526
# 50 reward =  239.4165886390919 , average =  260.1232841177688
# 51 reward =  -123.82122711418887 , average =  239.0839107735842
# 52 reward =  247.4985151694333 , average =  240.05918582677077
# 53 reward =  -105.92924972766306 , average =  219.41442647252197
# 54 reward =  275.22646005263624 , average =  220.71423588552315
# 55 reward =  239.25898703155863 , average =  220.69023575148262
# 56 reward =  273.74267430200206 , average =  221.94698356256578
# 57 reward =  269.57033470855845 , average =  221.243640088663
# 58 reward =  265.53868130855966 , average =  221.31905177986604
# 59 reward =  298.0088984194912 , average =  222.69839013832407
# 60 reward =  204.13503103869363 , average =  219.1206259863643
# 61 reward =  273.6458655294634 , average =  217.7681463557836
# 62 reward =  238.94037028266965 , average =  216.6123475411906
# 63 reward =  -90.59704023307133 , average =  200.28623682835638
# 64 reward =  306.171112357119 , average =  203.83330405770812
# 65 reward =  269.25685303591126 , average =  205.69774621188563
# 66 reward =  238.46038237552634 , average =  203.9686000067718
# 67 reward =  261.645847908581 , average =  202.24925579928157
# 68 reward =  251.1303467247829 , average =  201.6387472758356
# 69 reward =  260.1000463665955 , average =  204.56997390878755
# 70 reward =  -33.84665515899144 , average =  190.90681171888338
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-79-9e7c6565e554> in <cell line: 15>()
#      20     while True:
#      21         action, _ = sb3_model.predict(obs)
# ---> 22         obs, reward, done, truncated, _ = env.step(action)
#      23         episode_reward += reward
#      24
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/monitor.py in step(self, action)
#      91         """
#      92         if self.needs_reset:
# ---> 93             raise RuntimeError("Tried to step environment that needs reset")
#      94         observation, reward, terminated, truncated, info = self.env.step(action)
#      95         self.rewards.append(float(reward))
#
# RuntimeError: Tried to step environment that needs reset

# %%
env = gym.make("LunarLanderContinuous-v2")

# %%
# Training loop
num_episodes = 1000
episode_rewards = []
moving_average_rewards = []
for episode in range(num_episodes):
    obs = env.reset()[0]
    #print(obs)
    episode_reward = 0

    while True:
        action, _ = sb3_model.predict(obs)
        obs, reward, done, truncated, _ = env.step(action)
        episode_reward += reward

        if done:
            episode_rewards.append(episode_reward)

            # Calculate the moving average
            if len(episode_rewards) >= window_size:
                moving_average = np.mean(episode_rewards[-window_size:])
                moving_average_rewards.append(moving_average)
                #print(episode, "reward = ", episode_reward, ", average = ", moving_average)

            break

# %% [markdown]
# In a single plot, compare the performance of your implementation of the algorithm in Problem 1.1. with the one that you implemented above (Problem 1.4).

# %%
temp = DDPG(env)
temp.copy_params(agent_001)
# agent_001 = temp
# Out:
# Actor(
#   (input_layer): Linear(in_features=8, out_features=256, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (output_layer): Linear(in_features=256, out_features=2, bias=True)
# )
# actor update
# critic update

# %%
# Plot the rewards

plt.figure(figsize=(10, 6))
plt.plot(range(1, num_episodes + 1), episode_rewards, label="Episode Reward, SB3", alpha=0.5)
plt.plot(range(window_size, num_episodes + 1), moving_average_rewards, label=f"{window_size}-Episode Moving Average, SB3")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.legend()
plt.title("Episodic Rewards and Moving Average")
plt.grid()
temp.make_plot(0, 0, 1, default_scheme=0, movavg_color='r', show_instant=0)
plt.show()
